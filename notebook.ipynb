# %%
The printer kinematic system is rateher complicated
Starting with thw rotating bed.
the to angel the nozzle around the z axis the bed can rotate and with it the xy koordinate system. wit 0, 0 (YX) being in the middle.
In Cartesian Coordinates 2D that is [[x, 0], [0, y]]
When translated to a core XY kinematic:


U is an angle given in radians.
With Multiplied with the rotation matrix [[-sin(U), cos(U)], [sin(U), cos(U)]] we get:
[[-x * sin(U), 0], [0, y * cos(U)]]


in klippoer the c-helper file kkin_coreXY script tells derives the A and B stepper positions or movements
the formulas:
A = X + Y
B = X -Y
